# %% [markdown]
# https://jarroba.com/python-mongodb-driver-pymongo-con-ejemplos/

# %%
#pip install pymongo

# %%
from pymongo import MongoClient

# %%
class Futbolista:

    def __init__(self, nombre: str, apellidos: str, edad: int, internacional: bool):
        self.nombre = nombre
        self.apellidos = apellidos
        self.edad = edad
        self.internacional = internacional

    def toDBCollection(self):
        return {
            "nombre": self.nombre,
            "apellidos": self.apellidos,
            "edad": self.edad,
            "internacional": self.internacional
        }

    def __str__(self):
        return f"Nombre: {self.nombre} - Apellidos: {self.apellidos} - Edad: {self.edad} - Internacional: {self.internacional}"

# %%
# Creo una lista de objetos futbolista a insertar en la BD
futbolistas = [
    Futbolista('Iker','Casillas',33, True),
    Futbolista('Carles','Puyol',36,False),
    Futbolista('Sergio','Ramos',28,True),
    Futbolista('Andrés','Iniesta',30,True),
    Futbolista('Fernando','Torres',30,True),
    Futbolista('Leo','Baptistao',22,False),
    Futbolista('Juan','Baptistao',22,False),
    Futbolista('diego','Baptistao',22,False),
    Futbolista('camilo','Baptistao',22,False),
    Futbolista('Espin','Baptistao',22,False),
    Futbolista('Diego','Baptistao',22,False),
]

# %%
# PASO 1: Conexión al Server de MongoDB Pasandole el host y el puerto

client = MongoClient("mongodb+srv://cgiohidalgo:holamundo123@cluster0.gnjw3xg.mongodb.net/?retryWrites=true&w=majority")
#db = client.test

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)

db = client.Futbol

collection = db.Futbolistas
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
# PASO 4.1: "CREATE" -> Metemos los objetos futbolista (o documentos en Mongo) en la coleccion Futbolista
futbolistas_insertados = []
for futbolista in futbolistas:
    resultado = collection.insert_one(futbolista.toDBCollection())
    futbolistas_insertados.append(resultado.inserted_id)
#print("Futbolistas insertados: ", futbolistas_insertados)
print("Futbolistas insertados: ", futbolistas_insertados)
# Out:
# Futbolistas insertados:  [ObjectId('661cb5f9cf00a1cb8b4b19aa'), ObjectId('661cb5f9cf00a1cb8b4b19ab'), ObjectId('661cb5facf00a1cb8b4b19ac'), ObjectId('661cb5facf00a1cb8b4b19ad'), ObjectId('661cb5facf00a1cb8b4b19ae'), ObjectId('661cb5facf00a1cb8b4b19af'), ObjectId('661cb5fbcf00a1cb8b4b19b0'), ObjectId('661cb5fbcf00a1cb8b4b19b1'), ObjectId('661cb5fbcf00a1cb8b4b19b2'), ObjectId('661cb5fccf00a1cb8b4b19b3'), ObjectId('661cb5fccf00a1cb8b4b19b4')]

# %%
# Actualizar 
resultado  = collection.update_one({"nombre":"Andrés"}, {"$set": {"nombre":"Andrés Juan"}})

print("Documento actualizado: ", resultado.modified_count)

# Futbolista('Sergio','Ramos',28,True),
#    Futbolista('Andrés','Iniesta',30,True),



#Eliminar
# Out:
# Documento actualizado:  1

# %%
resultado = collection.find()

for fut in resultado:
    print(fut)
# Out:
# {'_id': ObjectId('643d8065b11171eb7c19d0aa'), 'nombre': 'Sergio', 'apellidos': 'Ramos', 'edad': 28, 'internacional': True}
# {'_id': ObjectId('643fe740a2f6ade80f5acfb8'), 'nombre': 'Andrés Juan', 'apellidos': 'Iniesta', 'edad': 30, 'internacional': True}
# {'_id': ObjectId('6446ad0a10e095638f9dad6b'), 'nombre': 'Andrés Juan', 'apellidos': 'Iniesta', 'edad': 30, 'internacional': True}
# {'_id': ObjectId('6446b1d1efac86b290dd0f97'), 'nombre': 'Sergio', 'apellidos': 'Ramos', 'edad': 28, 'internacional': True}
# {'_id': ObjectId('6446b357efac86b290dd0fa1'), 'Nombre': 'Iker', 'Apellidos': 'Casillas', 'Edad': 33, 'Internacional': True}
# {'_id': ObjectId('6446b3d5fc14fcefa7775efa'), 'Nombre': 'Carles', 'Apellidos': 'Puyol', 'Edad': 36, 'Internacional': False}
# {'_id': ObjectId('6446b3d5fc14fcefa7775efc'), 'Nombre': 'Andrés', 'Apellidos': 'Iniesta', 'Edad': 30, 'Internacional': True}
# {'_id': ObjectId('6446b5a26a55e13ae2b37df1'), 'Nombre': 'Carles', 'Apellidos': 'Puyol', 'Edad': 36, 'Internacional': False}
# {'_id': ObjectId('6446b604189e81ac835027ef'), 'nombre': 'Sergio', 'apellidos': 'Ramos', 'edad': 28, 'internacional': True}
# {'_id': ObjectId('6446b660189e81ac835027fc'), 'nombre': 'Andrés Juan', 'apellidos': 'Iniesta', 'edad': 30, 'internacional': True}
# {'_id': ObjectId('643d832d212a0ef1d288ebaa'), 'nombre': 'Fernando', 'apellidos': 'Torres', 'edad': 30, 'internacional': True}
# {'_id': ObjectId('643fe82fcda1dcd8c8061040'), 'nombre': 'Fernando', 'apellidos': 'Torres', 'edad': 30, 'internacional': True}
# {'_id': ObjectId('643ff09fb193b1dd77215a8a'), 'nombre': 'Sergio', 'apellidos': 'Ramos', 'edad': 28, 'internacional': True}
# {'_id': ObjectId('643ff09fb193b1dd77215a8c'), 'nombre': 'Fernando', 'apellidos': 'Torres', 'edad': 30, 'internacional': True}
# {'_id': ObjectId('6446ad0910e095638f9dad69'), 'nombre': 'Carles', 'apellidos': 'Puyol', 'edad': 65, 'internacional': False}
# {'_id': ObjectId('6446ad0a10e095638f9dad6c'), 'nombre': 'Fernando', 'apellidos': 'Torres', 'edad': 30, 'internacional': True}
# {'_id': ObjectId('6446b1d2efac86b290dd0f99'), 'nombre': 'Fernando', 'apellidos': 'Torres', 'edad': 30, 'internacional': True}
# {'_id': ObjectId('6446b42ffc14fcefa7775f0b'), 'Nombre': 'Juan', 'Apellidos': 'Baptistao', 'Edad': 22, 'Internacional': False}
# {'_id': ObjectId('6446b431fc14fcefa7775f0f'), 'Nombre': 'Diego', 'Apellidos': 'Baptistao', 'Edad': 22, 'Internacional': False}
# {'_id': ObjectId('6446b5a36a55e13ae2b37df3'), 'Nombre': 'Andrés', 'Apellidos': 'Iniesta', 'Edad': 30, 'Internacional': True}
# {'_id': ObjectId('6446b5a56a55e13ae2b37dfa'), 'Nombre': 'Diego', 'Apellidos': 'Baptistao', 'Edad': 22, 'Internacional': False}
# {'_id': ObjectId('643d82fb212a0ef1d288eb9d'), 'nombre': 'Sergio', 'apellidos': 'Ramos', 'edad': 28, 'internacional': True}
# {'_id': ObjectId('643fe5f298851cc89c169c2f'), 'Nombre': 'Carles', 'Edad': 65, 'Apellido': 'Puyol', 'Nacional': 1}
# {'_id': ObjectId('643fe82fcda1dcd8c806103e'), 'nombre': 'Sergio', 'apellidos': 'Ramos', 'edad': 28, 'internacional': True}
# {'_id': ObjectId('643ff09eb193b1dd77215a89'), 'nombre': 'Carles', 'apellidos': 'Puyol', 'edad': 65, 'internacional': False}
# {'_id': ObjectId('6446ad12efac86b290dd0f8a'), 'nombre': 'Carles', 'apellidos': 'Puyol', 'edad': 65, 'internacional': False}
# {'_id': ObjectId('6446b42ffc14fcefa7775f09'), 'Nombre': 'Fernando', 'Apellidos': 'Torres', 'Edad': 30, 'Internacional': True}
# {'_id': ObjectId('6446b5a46a55e13ae2b37df8'), 'Nombre': 'camilo', 'Apellidos': 'Baptistao', 'Edad': 22, 'Internacional': False}
# {'_id': ObjectId('6446b660189e81ac835027fb'), 'nombre': 'Sergio', 'apellidos': 'Ramos', 'edad': 28, 'internacional': True}
# {'_id': ObjectId('6446b661189e81ac835027fd'), 'nombre': 'Fernando', 'apellidos': 'Torres', 'edad': 30, 'internacional': True}
# {'_id': ObjectId('643d82fb212a0ef1d288eb9c'), 'nombre': 'Carles', 'apellidos': 'Puyol', 'edad': 65, 'internacional': False}
# {'_id': ObjectId('643d832c212a0ef1d288eba8'), 'nombre': 'Sergio', 'apellidos': 'Ramos', 'edad': 28, 'internacional': True}
# {'_id': ObjectId('643fe441c87fb840a2285ddb'), 'nombre': 'Sergio', 'apellidos': 'Ramos', 'edad': 28, 'internacional': True}
# {'_id': ObjectId('643fe441c87fb840a2285ddd'), 'nombre': 'Fernando', 'apellidos': 'Torres', 'edad': 30, 'internacional': True}
# {'_id': ObjectId('643fe51450519dd7950d0f27'), 'nombre': 'Andrés Juan', 'apellidos': 'Iniesta', 'edad': 30, 'internacional': True}
# {'_id': ObjectId('643fe82fcda1dcd8c806103f'), 'nombre': 'Andrés Juan', 'apellidos': 'Iniesta', 'edad': 30, 'internacional': True}
# {'_id': ObjectId('6446b1d1efac86b290dd0f96'), 'nombre': 'Carles', 'apellidos': 'Puyol', 'edad': 65, 'internacional': False}
# {'_id': ObjectId('6446b22a10e095638f9dad83'), 'nombre': 'Andrés Juan', 'apellidos': 'Iniesta', 'edad': 30, 'internacional': True}
# {'_id': ObjectId('6446b604189e81ac835027ee'), 'nombre': 'Carles', 'apellidos': 'Puyol', 'edad': 65, 'internacional': False}
# {'_id': ObjectId('64485425ec7483b941f9d7f9'), 'Nombre': 'Leo', 'Apellido': 'Baptistao', 'Edad': 22, 'Internacional': False}
# {'_id': ObjectId('643d7af4212a0ef1d288eb96'), 'nombre': 'Carles', 'apellidos': 'Puyol', 'edad': 65, 'internacional': 1}
# {'_id': ObjectId('643f5aa8a25946234c8eefd4'), 'nombre': 'Fernando', 'apellidos': 'Torres', 'edad': 30, 'internacional': True}
# {'_id': ObjectId('643fe59750519dd7950d0f31'), 'nombre': 'Carles', 'apellidos': 'Puyol', 'edad': 65, 'internacional': False}
# {'_id': ObjectId('643fe8e5d1b62c941cc5f406'), 'nombre': 'Carles', 'apellidos': 'Puyol', 'edad': 65, 'internacional': False}
# {'_id': ObjectId('6446b1ae10e095638f9dad77'), 'nombre': 'Andrés Juan', 'apellidos': 'Iniesta', 'edad': 30, 'internacional': True}
# {'_id': ObjectId('6446b22a10e095638f9dad84'), 'nombre': 'Fernando', 'apellidos': 'Torres', 'edad': 30, 'internacional': True}
# {'_id': ObjectId('6446b3704b71683ad64649c3'), 'Nombre': 'Juan', 'Apellidos': 'Baptistao', 'Edad': 22, 'Internacional': False}
# {'_id': ObjectId('6446b3d6fc14fcefa7775efe'), 'Nombre': 'Leo', 'Apellidos': 'Baptistao', 'Edad': 22, 'Internacional': False}
# {'_id': ObjectId('6446b42efc14fcefa7775f05'), 'Nombre': 'Iker', 'Apellidos': 'Casillas', 'Edad': 33, 'Internacional': True}
# {'_id': ObjectId('6446b660189e81ac835027fa'), 'nombre': 'Carles', 'apellidos': 'Puyol', 'edad': 65, 'internacional': False}
# {'_id': ObjectId('64485426ec7483b941f9d7fd'), 'Nombre': 'Espin', 'Apellido': 'Baptistao', 'Edad': 22, 'Internacional': False}
# {'_id': ObjectId('643d832c212a0ef1d288eba7'), 'nombre': 'Carles', 'apellidos': 'Puyol', 'edad': 65, 'internacional': False}
# {'_id': ObjectId('643d832c212a0ef1d288eba9'), 'nombre': 'Andrés Juan', 'apellidos': 'Iniesta', 'edad': 30, 'internacional': True}
# {'_id': ObjectId('643fe440c87fb840a2285dda'), 'nombre': 'Carles', 'apellidos': 'Puyol', 'edad': 65, 'internacional': False}
# {'_id': ObjectId('643fe59850519dd7950d0f33'), 'nombre': 'Andrés Juan', 'apellidos': 'Iniesta', 'edad': 30, 'internacional': True}
# {'_id': ObjectId('6446ad13efac86b290dd0f8b'), 'nombre': 'Sergio', 'apellidos': 'Ramos', 'edad': 28, 'internacional': True}
# {'_id': ObjectId('6446b358efac86b290dd0fa7'), 'Nombre': 'Juan', 'Apellidos': 'Baptistao', 'Edad': 22, 'Internacional': False}
# {'_id': ObjectId('6446b359efac86b290dd0fa8'), 'Nombre': 'diego', 'Apellidos': 'Baptistao', 'Edad': 22, 'Internacional': False}
# {'_id': ObjectId('6446b36f4b71683ad64649bf'), 'Nombre': 'Sergio', 'Apellidos': 'Ramos', 'Edad': 28, 'Internacional': True}
# {'_id': ObjectId('6446b5a26a55e13ae2b37df2'), 'Nombre': 'Sergio', 'Apellidos': 'Ramos', 'Edad': 28, 'Internacional': True}
# {'_id': ObjectId('6446b5a36a55e13ae2b37df4'), 'Nombre': 'Fernando', 'Apellidos': 'Torres', 'Edad': 30, 'Internacional': True}
# {'_id': ObjectId('64485426ec7483b941f9d7fe'), 'Nombre': 'Diego', 'Apellido': 'Baptistao', 'Edad': 22, 'Internacional': False}
# {'_id': ObjectId('643d82fc212a0ef1d288eb9e'), 'nombre': 'Andrés Juan', 'apellidos': 'Iniesta', 'edad': 30, 'internacional': True}
# {'_id': ObjectId('643d82fc212a0ef1d288eb9f'), 'nombre': 'Fernando', 'apellidos': 'Torres', 'edad': 30, 'internacional': True}
# {'_id': ObjectId('643fe8e5d1b62c941cc5f407'), 'nombre': 'Sergio', 'apellidos': 'Ramos', 'edad': 28, 'internacional': True}
# {'_id': ObjectId('6446b357efac86b290dd0fa2'), 'Nombre': 'Carles', 'Apellidos': 'Puyol', 'Edad': 36, 'Internacional': False}
# {'_id': ObjectId('6446b358efac86b290dd0fa5'), 'Nombre': 'Fernando', 'Apellidos': 'Torres', 'Edad': 30, 'Internacional': True}
# {'_id': ObjectId('6446b42efc14fcefa7775f07'), 'Nombre': 'Sergio', 'Apellidos': 'Ramos', 'Edad': 28, 'Internacional': True}
# {'_id': ObjectId('6446b430fc14fcefa7775f0e'), 'Nombre': 'Espin', 'Apellidos': 'Baptistao', 'Edad': 22, 'Internacional': False}
# {'_id': ObjectId('6446b5a46a55e13ae2b37df7'), 'Nombre': 'diego', 'Apellidos': 'Baptistao', 'Edad': 22, 'Internacional': False}
# {'_id': ObjectId('64485422ec7483b941f9d7f4'), 'Nombre': 'Iker', 'Apellido': 'Casillas', 'Edad': 33, 'Internacional': True}
# {'_id': ObjectId('643fe59750519dd7950d0f32'), 'nombre': 'Sergio', 'apellidos': 'Ramos', 'edad': 28, 'internacional': True}
# {'_id': ObjectId('643fe8e5d1b62c941cc5f409'), 'nombre': 'Fernando', 'apellidos': 'Torres', 'edad': 30, 'internacional': True}
# {'_id': ObjectId('6446b358efac86b290dd0fa6'), 'Nombre': 'Leo', 'Apellidos': 'Baptistao', 'Edad': 22, 'Internacional': False}
# {'_id': ObjectId('6446b359efac86b290dd0faa'), 'Nombre': 'Espin', 'Apellidos': 'Baptistao', 'Edad': 22, 'Internacional': False}
# {'_id': ObjectId('6446b36e4b71683ad64649bd'), 'Nombre': 'Iker', 'Apellidos': 'Casillas', 'Edad': 33, 'Internacional': True}
# {'_id': ObjectId('6446b3704b71683ad64649c2'), 'Nombre': 'Leo', 'Apellidos': 'Baptistao', 'Edad': 22, 'Internacional': False}
# {'_id': ObjectId('6446b3d5fc14fcefa7775efb'), 'Nombre': 'Sergio', 'Apellidos': 'Ramos', 'Edad': 28, 'Internacional': True}
# {'_id': ObjectId('6446b3d7fc14fcefa7775f01'), 'Nombre': 'camilo', 'Apellidos': 'Baptistao', 'Edad': 22, 'Internacional': False}
# {'_id': ObjectId('643d8065b11171eb7c19d0ab'), 'nombre': 'Andrés Juan', 'apellidos': 'Iniesta', 'edad': 30, 'internacional': True}
# {'_id': ObjectId('643f5aa7a25946234c8eefd2'), 'nombre': 'Sergio', 'apellidos': 'Ramos', 'edad': 28, 'internacional': True}
# {'_id': ObjectId('643fe4583795a93c17ab44c2'), 'nombre': 'Sergio', 'apellidos': 'Ramos', 'edad': 28, 'internacional': True}
# {'_id': ObjectId('643fe740a2f6ade80f5acfb6'), 'nombre': 'Carles', 'apellidos': 'Puyol', 'edad': 65, 'internacional': False}
# {'_id': ObjectId('643ff09fb193b1dd77215a8b'), 'nombre': 'Andrés Juan', 'apellidos': 'Iniesta', 'edad': 30, 'internacional': True}
# {'_id': ObjectId('6446b22a10e095638f9dad82'), 'nombre': 'Sergio', 'apellidos': 'Ramos', 'edad': 28, 'internacional': True}
# {'_id': ObjectId('6446b357efac86b290dd0fa4'), 'Nombre': 'Andrés', 'Apellidos': 'Iniesta', 'Edad': 30, 'Internacional': True}
# {'_id': ObjectId('6446b359efac86b290dd0fab'), 'Nombre': 'Diego', 'Apellidos': 'Baptistao', 'Edad': 22, 'Internacional': False}
# {'_id': ObjectId('6446b36f4b71683ad64649c1'), 'Nombre': 'Fernando', 'Apellidos': 'Torres', 'Edad': 30, 'Internacional': True}
# {'_id': ObjectId('6446b3714b71683ad64649c5'), 'Nombre': 'camilo', 'Apellidos': 'Baptistao', 'Edad': 22, 'Internacional': False}
# {'_id': ObjectId('6446b3d4fc14fcefa7775ef9'), 'Nombre': 'Iker', 'Apellidos': 'Casillas', 'Edad': 33, 'Internacional': True}
# {'_id': ObjectId('6446b3d6fc14fcefa7775eff'), 'Nombre': 'Juan', 'Apellidos': 'Baptistao', 'Edad': 22, 'Internacional': False}
# {'_id': ObjectId('6446b66224e335670e80ceff'), 'nombre': 'Sergio', 'apellidos': 'Ramos', 'edad': 28, 'internacional': True}
# {'_id': ObjectId('6446b66224e335670e80cf01'), 'nombre': 'Fernando', 'apellidos': 'Torres', 'edad': 30, 'internacional': True}
# {'_id': ObjectId('64485424ec7483b941f9d7f8'), 'Nombre': 'Fernando', 'Apellido': 'Torres', 'Edad': 30, 'Internacional': True}
# {'_id': ObjectId('643fe4583795a93c17ab44c1'), 'nombre': 'Carles', 'apellidos': 'Puyol', 'edad': 65, 'internacional': False}
# {'_id': ObjectId('643fe5f398851cc89c169c30'), 'Nombre': 'Sergio', 'Edad': 28, 'Apellido': 'Ramos', 'Nacional': True}
# {'_id': ObjectId('6446b5a46a55e13ae2b37df6'), 'Nombre': 'Juan', 'Apellidos': 'Baptistao', 'Edad': 22, 'Internacional': False}
# {'_id': ObjectId('64485424ec7483b941f9d7f6'), 'Nombre': 'Sergio', 'Apellido': 'Ramos', 'Edad': 28, 'Internacional': True}
# {'_id': ObjectId('64485425ec7483b941f9d7fa'), 'Nombre': 'Juan', 'Apellido': 'Baptistao', 'Edad': 22, 'Internacional': False}
# {'_id': ObjectId('643d7af4212a0ef1d288eb97'), 'nombre': 'Sergio', 'apellidos': 'Ramos', 'edad': 28, 'internacional': True}
# {'_id': ObjectId('643d8064b11171eb7c19d0a9'), 'nombre': 'Carles', 'apellidos': 'Puyol', 'edad': 65, 'internacional': 1}
# {'_id': ObjectId('643f5aa7a25946234c8eefd1'), 'nombre': 'Carles', 'apellidos': 'Puyol', 'edad': 65, 'internacional': False}
# {'_id': ObjectId('643fe51450519dd7950d0f28'), 'nombre': 'Fernando', 'apellidos': 'Torres', 'edad': 30, 'internacional': True}
# {'_id': ObjectId('643fe5f398851cc89c169c32'), 'Nombre': 'Fernando', 'Edad': 30, 'Apellido': 'Torres', 'Nacional': True}
# {'_id': ObjectId('643fe740a2f6ade80f5acfb7'), 'nombre': 'Sergio', 'apellidos': 'Ramos', 'edad': 28, 'internacional': True}
# {'_id': ObjectId('6446ad0910e095638f9dad6a'), 'nombre': 'Sergio', 'apellidos': 'Ramos', 'edad': 28, 'internacional': True}
# {'_id': ObjectId('6446ad13efac86b290dd0f8d'), 'nombre': 'Fernando', 'apellidos': 'Torres', 'edad': 30, 'internacional': True}
# {'_id': ObjectId('6446b1ae10e095638f9dad78'), 'nombre': 'Fernando', 'apellidos': 'Torres', 'edad': 30, 'internacional': True}
# {'_id': ObjectId('6446b359efac86b290dd0fa9'), 'Nombre': 'camilo', 'Apellidos': 'Baptistao', 'Edad': 22, 'Internacional': False}
# {'_id': ObjectId('6446b3714b71683ad64649c7'), 'Nombre': 'Diego', 'Apellidos': 'Baptistao', 'Edad': 22, 'Internacional': False}
# {'_id': ObjectId('6446b42efc14fcefa7775f06'), 'Nombre': 'Carles', 'Apellidos': 'Puyol', 'Edad': 36, 'Internacional': False}
# {'_id': ObjectId('6446b42ffc14fcefa7775f08'), 'Nombre': 'Andrés', 'Apellidos': 'Iniesta', 'Edad': 30, 'Internacional': True}
# {'_id': ObjectId('6446b5a46a55e13ae2b37df9'), 'Nombre': 'Espin', 'Apellidos': 'Baptistao', 'Edad': 22, 'Internacional': False}
# {'_id': ObjectId('64492aa7c150ae46320e693d'), 'nombre': 'Andrés Juan', 'apellidos': 'Iniesta', 'edad': 30, 'internacional': True}
# {'_id': ObjectId('64492aa7c150ae46320e693e'), 'nombre': 'Fernando', 'apellidos': 'Torres', 'edad': 30, 'internacional': True}
# {'_id': ObjectId('643f5aa8a25946234c8eefd3'), 'nombre': 'Andrés Juan', 'apellidos': 'Iniesta', 'edad': 30, 'internacional': True}
# {'_id': ObjectId('643fe4583795a93c17ab44c3'), 'nombre': 'Andrés Juan', 'apellidos': 'Iniesta', 'edad': 30, 'internacional': True}
# {'_id': ObjectId('643fe5f398851cc89c169c31'), 'Nombre': 'Andrés Juan', 'Edad': 30, 'Apellido': 'Iniesta', 'Nacional': True}
# {'_id': ObjectId('6446b36f4b71683ad64649c0'), 'Nombre': 'Andrés', 'Apellidos': 'Iniesta', 'Edad': 30, 'Internacional': True}
# {'_id': ObjectId('64485426ec7483b941f9d7fc'), 'Nombre': 'camilo', 'Apellido': 'Baptistao', 'Edad': 22, 'Internacional': False}
# {'_id': ObjectId('643d7af5212a0ef1d288eb99'), 'nombre': 'Fernando', 'apellidos': 'Torres', 'edad': 30, 'internacional': True}
# {'_id': ObjectId('643d8065b11171eb7c19d0ac'), 'nombre': 'Fernando', 'apellidos': 'Torres', 'edad': 30, 'internacional': True}
# {'_id': ObjectId('643fe441c87fb840a2285ddc'), 'nombre': 'Andrés Juan', 'apellidos': 'Iniesta', 'edad': 30, 'internacional': True}
# {'_id': ObjectId('643fe51350519dd7950d0f26'), 'nombre': 'Sergio', 'apellidos': 'Ramos', 'edad': 28, 'internacional': True}
# {'_id': ObjectId('6446b36e4b71683ad64649be'), 'Nombre': 'Carles', 'Apellidos': 'Puyol', 'Edad': 36, 'Internacional': False}
# {'_id': ObjectId('6446b3d6fc14fcefa7775efd'), 'Nombre': 'Fernando', 'Apellidos': 'Torres', 'Edad': 30, 'Internacional': True}
# {'_id': ObjectId('6446b430fc14fcefa7775f0c'), 'Nombre': 'diego', 'Apellidos': 'Baptistao', 'Edad': 22, 'Internacional': False}
# {'_id': ObjectId('6446b66224e335670e80cf00'), 'nombre': 'Andrés Juan', 'apellidos': 'Iniesta', 'edad': 30, 'internacional': True}
# {'_id': ObjectId('64485424ec7483b941f9d7f7'), 'Nombre': 'Andrés', 'Apellido': 'Iniesta', 'Edad': 30, 'Internacional': True}
# {'_id': ObjectId('643fe82fcda1dcd8c806103d'), 'nombre': 'Carles', 'apellidos': 'Puyol', 'edad': 65, 'internacional': False}
# {'_id': ObjectId('6446ad13efac86b290dd0f8c'), 'nombre': 'Andrés Juan', 'apellidos': 'Iniesta', 'edad': 30, 'internacional': True}
# {'_id': ObjectId('6446b1ad10e095638f9dad75'), 'nombre': 'Carles', 'apellidos': 'Puyol', 'edad': 65, 'internacional': False}
# {'_id': ObjectId('6446b1ae10e095638f9dad76'), 'nombre': 'Sergio', 'apellidos': 'Ramos', 'edad': 28, 'internacional': True}
# {'_id': ObjectId('6446b22910e095638f9dad81'), 'nombre': 'Carles', 'apellidos': 'Puyol', 'edad': 65, 'internacional': False}
# {'_id': ObjectId('6446b3704b71683ad64649c4'), 'Nombre': 'diego', 'Apellidos': 'Baptistao', 'Edad': 22, 'Internacional': False}
# {'_id': ObjectId('6446b3d6fc14fcefa7775f00'), 'Nombre': 'diego', 'Apellidos': 'Baptistao', 'Edad': 22, 'Internacional': False}
# {'_id': ObjectId('6446b604189e81ac835027f0'), 'nombre': 'Andrés Juan', 'apellidos': 'Iniesta', 'edad': 30, 'internacional': True}
# {'_id': ObjectId('6446b66124e335670e80cefe'), 'nombre': 'Carles', 'apellidos': 'Puyol', 'edad': 65, 'internacional': False}
# {'_id': ObjectId('643d7af5212a0ef1d288eb98'), 'nombre': 'Andrés Juan', 'apellidos': 'Iniesta', 'edad': 30, 'internacional': True}
# {'_id': ObjectId('643fe741a2f6ade80f5acfb9'), 'nombre': 'Fernando', 'apellidos': 'Torres', 'edad': 30, 'internacional': True}
# {'_id': ObjectId('6446b357efac86b290dd0fa3'), 'Nombre': 'Sergio', 'Apellidos': 'Ramos', 'Edad': 28, 'Internacional': True}
# {'_id': ObjectId('6446b3d7fc14fcefa7775f02'), 'Nombre': 'Espin', 'Apellidos': 'Baptistao', 'Edad': 22, 'Internacional': False}
# {'_id': ObjectId('6446b42ffc14fcefa7775f0a'), 'Nombre': 'Leo', 'Apellidos': 'Baptistao', 'Edad': 22, 'Internacional': False}
# {'_id': ObjectId('6446b430fc14fcefa7775f0d'), 'Nombre': 'camilo', 'Apellidos': 'Baptistao', 'Edad': 22, 'Internacional': False}
# {'_id': ObjectId('64485424ec7483b941f9d7f5'), 'Nombre': 'Carles', 'Apellido': 'Puyol', 'Edad': 36, 'Internacional': False}
# {'_id': ObjectId('643fe4583795a93c17ab44c4'), 'nombre': 'Fernando', 'apellidos': 'Torres', 'edad': 30, 'internacional': True}
# {'_id': ObjectId('643fe51350519dd7950d0f25'), 'nombre': 'Carles', 'apellidos': 'Puyol', 'edad': 65, 'internacional': False}
# {'_id': ObjectId('643fe59850519dd7950d0f34'), 'nombre': 'Fernando', 'apellidos': 'Torres', 'edad': 30, 'internacional': True}
# {'_id': ObjectId('643fe8e5d1b62c941cc5f408'), 'nombre': 'Andrés Juan', 'apellidos': 'Iniesta', 'edad': 30, 'internacional': True}
# {'_id': ObjectId('6446b1d2efac86b290dd0f98'), 'nombre': 'Andrés Juan', 'apellidos': 'Iniesta', 'edad': 30, 'internacional': True}
# {'_id': ObjectId('6446b3714b71683ad64649c6'), 'Nombre': 'Espin', 'Apellidos': 'Baptistao', 'Edad': 22, 'Internacional': False}
# {'_id': ObjectId('6446b3d7fc14fcefa7775f03'), 'Nombre': 'Diego', 'Apellidos': 'Baptistao', 'Edad': 22, 'Internacional': False}
# {'_id': ObjectId('6446b5a26a55e13ae2b37df0'), 'Nombre': 'Iker', 'Apellidos': 'Casillas', 'Edad': 33, 'Internacional': True}
# {'_id': ObjectId('6446b5a36a55e13ae2b37df5'), 'Nombre': 'Leo', 'Apellidos': 'Baptistao', 'Edad': 22, 'Internacional': False}
# {'_id': ObjectId('6446b605189e81ac835027f1'), 'nombre': 'Fernando', 'apellidos': 'Torres', 'edad': 30, 'internacional': True}
# {'_id': ObjectId('64485425ec7483b941f9d7fb'), 'Nombre': 'diego', 'Apellido': 'Baptistao', 'Edad': 22, 'Internacional': False}
# {'_id': ObjectId('64492aa6c150ae46320e693b'), 'nombre': 'Carles', 'apellidos': 'Puyol', 'edad': 65, 'internacional': False}
# {'_id': ObjectId('64492aa7c150ae46320e693c'), 'nombre': 'Sergio', 'apellidos': 'Ramos', 'edad': 28, 'internacional': True}
# {'_id': ObjectId('65f36c31813cf9652c0d838d'), 'nombre': 'Carles', 'apellidos': 'Puyol', 'edad': 65, 'internacional': 1}
# {'_id': ObjectId('65f36c31813cf9652c0d838e'), 'nombre': 'Sergio', 'apellidos': 'Ramos', 'edad': 28, 'internacional': True}
# {'_id': ObjectId('65f36c32813cf9652c0d838f'), 'nombre': 'Andrés Juan', 'apellidos': 'Iniesta', 'edad': 30, 'internacional': True}
# {'_id': ObjectId('65f36c32813cf9652c0d8390'), 'nombre': 'Fernando', 'apellidos': 'Torres', 'edad': 30, 'internacional': True}
# {'_id': ObjectId('661690b3517695e3f4abf257'), 'nombre': 'Carles', 'apellidos': 'Puyol', 'edad': 65, 'internacional': False}
# {'_id': ObjectId('661690b3517695e3f4abf258'), 'nombre': 'Sergio', 'apellidos': 'Ramos', 'edad': 28, 'internacional': True}
# {'_id': ObjectId('661690b3517695e3f4abf259'), 'nombre': 'Andrés Juan', 'apellidos': 'Iniesta', 'edad': 30, 'internacional': True}
# {'_id': ObjectId('661690b4517695e3f4abf25a'), 'nombre': 'Fernando', 'apellidos': 'Torres', 'edad': 30, 'internacional': True}
# {'_id': ObjectId('661692f93e3dd670d702f4bd'), 'nombre': 'Carles', 'apellidos': 'Puyol', 'edad': 65, 'internacional': False}
# {'_id': ObjectId('661692f93e3dd670d702f4be'), 'nombre': 'Sergio', 'apellidos': 'Ramos', 'edad': 28, 'internacional': True}
# {'_id': ObjectId('661692f93e3dd670d702f4bf'), 'nombre': 'Andrés Juan', 'apellidos': 'Iniesta', 'edad': 30, 'internacional': True}
# {'_id': ObjectId('661692f93e3dd670d702f4c0'), 'nombre': 'Fernando', 'apellidos': 'Torres', 'edad': 30, 'internacional': True}
# {'_id': ObjectId('66169368517695e3f4abf263'), 'nombre': 'Carles', 'apellidos': 'Puyol', 'edad': 65, 'internacional': False}
# {'_id': ObjectId('66169368517695e3f4abf264'), 'nombre': 'Sergio', 'apellidos': 'Ramos', 'edad': 28, 'internacional': True}
# {'_id': ObjectId('66169368517695e3f4abf265'), 'nombre': 'Andrés Juan', 'apellidos': 'Iniesta', 'edad': 30, 'internacional': True}
# {'_id': ObjectId('66169369517695e3f4abf266'), 'nombre': 'Fernando', 'apellidos': 'Torres', 'edad': 30, 'internacional': True}
# {'_id': ObjectId('661693b9517695e3f4abf26e'), 'nombre': 'Iker', 'apellidos': 'Casillas', 'edad': 65, 'internacional': True}
# {'_id': ObjectId('661693b9517695e3f4abf26f'), 'nombre': 'Carles', 'apellidos': 'Puyol', 'edad': 65, 'internacional': False}
# {'_id': ObjectId('661693b9517695e3f4abf270'), 'nombre': 'Sergio', 'apellidos': 'Ramos', 'edad': 28, 'internacional': True}
# {'_id': ObjectId('661693ba517695e3f4abf271'), 'nombre': 'Andrés Juan', 'apellidos': 'Iniesta', 'edad': 30, 'internacional': True}
# {'_id': ObjectId('661693ba517695e3f4abf272'), 'nombre': 'Fernando', 'apellidos': 'Torres', 'edad': 30, 'internacional': True}
# {'_id': ObjectId('661cb5f9cf00a1cb8b4b19aa'), 'nombre': 'Iker', 'apellidos': 'Casillas', 'edad': 33, 'internacional': True}
# {'_id': ObjectId('661cb5f9cf00a1cb8b4b19ab'), 'nombre': 'Carles', 'apellidos': 'Puyol', 'edad': 36, 'internacional': False}
# {'_id': ObjectId('661cb5facf00a1cb8b4b19ac'), 'nombre': 'Sergio', 'apellidos': 'Ramos', 'edad': 28, 'internacional': True}
# {'_id': ObjectId('661cb5facf00a1cb8b4b19ad'), 'nombre': 'Andrés', 'apellidos': 'Iniesta', 'edad': 30, 'internacional': True}
# {'_id': ObjectId('661cb5facf00a1cb8b4b19ae'), 'nombre': 'Fernando', 'apellidos': 'Torres', 'edad': 30, 'internacional': True}
# {'_id': ObjectId('661cb5facf00a1cb8b4b19af'), 'nombre': 'Leo', 'apellidos': 'Baptistao', 'edad': 22, 'internacional': False}
# {'_id': ObjectId('661cb5fbcf00a1cb8b4b19b0'), 'nombre': 'Juan', 'apellidos': 'Baptistao', 'edad': 22, 'internacional': False}
# {'_id': ObjectId('661cb5fbcf00a1cb8b4b19b1'), 'nombre': 'diego', 'apellidos': 'Baptistao', 'edad': 22, 'internacional': False}
# {'_id': ObjectId('661cb5fbcf00a1cb8b4b19b2'), 'nombre': 'camilo', 'apellidos': 'Baptistao', 'edad': 22, 'internacional': False}
# {'_id': ObjectId('661cb5fccf00a1cb8b4b19b3'), 'nombre': 'Espin', 'apellidos': 'Baptistao', 'edad': 22, 'internacional': False}
# {'_id': ObjectId('661cb5fccf00a1cb8b4b19b4'), 'nombre': 'Diego', 'apellidos': 'Baptistao', 'edad': 22, 'internacional': False}

# %%
resultado = collection.delete_one({"nombre": "Iker"})

if resultado.deleted_count == 1:
    print("Se elimino el documento")
else:
    print("No se elimino el documento")
# Out:
# Se elimino el documento

# %%
resultado  = collection.update_many({"nombre": {"$in": ["Iker", "Carles"]}}, {"$set": {"edad": 65}})

print (f"se actualziaron {resultado.modified_count} documentos")
# Out:
# se actualziaron 2 documentos

# %%
resultado = collection.delete_many({"apellidos": {"$regex":"^B"}})


if resultado.deleted_count == 1:
    print("Se elimino el documento")
else:
    print("No se elimino el documento")
# Out:
# No se elimino el documento

# %%
print(futbolistas[0])
# Out:
# Nombre: Iker - Apellidos: Casillas - Edad: 33 - Internacional: True

# %%
import matplotlib.pyplot as plt

# Lista de nombres y edades de los futbolistas
nombres = [futbolista.nombre for futbolista in futbolistas]
edades = [futbolista.edad for futbolista in futbolistas]

# Crear un gráfico de barras
plt.bar(nombres, edades)

# Agregar etiquetas a los ejes
plt.xlabel('Nombre')
plt.ylabel('Edad')

# Mostrar el gráfico
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Query the collection to get the ages of all the players
ages = collection.distinct('edad')

# Count the number of players for each age
counts = [collection.count_documents({'edad': age}) for age in ages]

# Create a bar chart using Matplotlib
plt.bar(ages, counts)
plt.title('Number of players by age')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %%
import matplotlib.pyplot as plt

# Count the number of international and non-international players
num_international = collection.count_documents({'internacional': True})
num_non_international = collection.count_documents({'internacional': False})

# Create a pie chart using Matplotlib
labels = ['International', 'Non-International']
sizes = [num_international, num_non_international]
explode = (0.1, 0)

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', startangle=90)
ax1.axis('equal')

plt.title('Percentage of international and non-international players')
plt.show()

# %%
import matplotlib.pyplot as plt

# Get the ages of all players in the collection
ages = [futbolista["edad"] for futbolista in collection.find()]



# Create a histogram using Matplotlib
plt.hist(ages, bins=10, color='green')

plt.title('Distribution of player ages')
plt.xlabel('Age')
plt.ylabel('Frequency')

plt.show()

# %%
#pip install pandas

# %%
import pandas as pd

# %%
resultado = collection.find() # es para ver todos los registros de la base de datos

documentos = [] #crear una lista (array)  para guardar los documentos


for documento in resultado:
    documentos.append(documento)
    
df =  pd.DataFrame(documentos)

df
# Out:
#                          _id       nombre apellidos  edad internacional
# 0   643d7af4212a0ef1d288eb96       Carles     Puyol    65             1
# 1   643d7af4212a0ef1d288eb97       Sergio     Ramos    28          True
# 2   643d7af5212a0ef1d288eb98  Andrés Juan   Iniesta    30          True
# 3   643d7af5212a0ef1d288eb99     Fernando    Torres    30          True
# 4   643d8064b11171eb7c19d0a9       Carles     Puyol    65             1
# 5   643d8065b11171eb7c19d0aa       Sergio     Ramos    28          True
# 6   643d8065b11171eb7c19d0ab  Andrés Juan   Iniesta    30          True
# 7   643d8065b11171eb7c19d0ac     Fernando    Torres    30          True
# 8   643d82fb212a0ef1d288eb9c       Carles     Puyol    65         False
# 9   643d82fb212a0ef1d288eb9d       Sergio     Ramos    28          True
# 10  643d82fc212a0ef1d288eb9e  Andrés Juan   Iniesta    30          True
# 11  643d82fc212a0ef1d288eb9f     Fernando    Torres    30          True
# 12  643d832c212a0ef1d288eba7       Carles     Puyol    65         False
# 13  643d832c212a0ef1d288eba8       Sergio     Ramos    28          True
# 14  643d832c212a0ef1d288eba9  Andrés Juan   Iniesta    30          True
# 15  643d832d212a0ef1d288ebaa     Fernando    Torres    30          True
# 16  643f5aa7a25946234c8eefd0         Iker  Casillas    65          True
# 17  643f5aa7a25946234c8eefd1       Carles     Puyol    65         False
# 18  643f5aa7a25946234c8eefd2       Sergio     Ramos    28          True
# 19  643f5aa8a25946234c8eefd3       Andrés   Iniesta    30          True
# 20  643f5aa8a25946234c8eefd4     Fernando    Torres    30          True
# 21  643fe440c87fb840a2285dd9         Iker  Casillas    65          True
# 22  643fe440c87fb840a2285dda       Carles     Puyol    65         False
# 23  643fe441c87fb840a2285ddb       Sergio     Ramos    28          True
# 24  643fe441c87fb840a2285ddc       Andrés   Iniesta    30          True
# 25  643fe441c87fb840a2285ddd     Fernando    Torres    30          True

# %%
df.shape #ver el numero de filas y columnas
# Out:
# (26, 5)

# %%
df.info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   _id            26 non-null     object
#  1   nombre         26 non-null     object
#  2   apellidos      26 non-null     object
#  3   edad           26 non-null     int64
#  4   internacional  26 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 1.1+ KB

# %%
df["edad"].describe()
#df.edad.describe()
# Out:
# count    26.000000
# mean     40.307692
# std      16.806592
# min      28.000000
# 25%      30.000000
# 50%      30.000000
# 75%      65.000000
# max      65.000000
# Name: edad, dtype: float64

# %%
df
# Out:
#                          _id       nombre apellidos  edad internacional
# 0   643d7af4212a0ef1d288eb96       Carles     Puyol    65             1
# 1   643d7af4212a0ef1d288eb97       Sergio     Ramos    28          True
# 2   643d7af5212a0ef1d288eb98  Andrés Juan   Iniesta    30          True
# 3   643d7af5212a0ef1d288eb99     Fernando    Torres    30          True
# 4   643d8064b11171eb7c19d0a9       Carles     Puyol    65             1
# 5   643d8065b11171eb7c19d0aa       Sergio     Ramos    28          True
# 6   643d8065b11171eb7c19d0ab  Andrés Juan   Iniesta    30          True
# 7   643d8065b11171eb7c19d0ac     Fernando    Torres    30          True
# 8   643d82fb212a0ef1d288eb9c       Carles     Puyol    65         False
# 9   643d82fb212a0ef1d288eb9d       Sergio     Ramos    28          True
# 10  643d82fc212a0ef1d288eb9e  Andrés Juan   Iniesta    30          True
# 11  643d82fc212a0ef1d288eb9f     Fernando    Torres    30          True
# 12  643d832c212a0ef1d288eba7       Carles     Puyol    65         False
# 13  643d832c212a0ef1d288eba8       Sergio     Ramos    28          True
# 14  643d832c212a0ef1d288eba9  Andrés Juan   Iniesta    30          True
# 15  643d832d212a0ef1d288ebaa     Fernando    Torres    30          True
# 16  643f5aa7a25946234c8eefd0         Iker  Casillas    65          True
# 17  643f5aa7a25946234c8eefd1       Carles     Puyol    65         False
# 18  643f5aa7a25946234c8eefd2       Sergio     Ramos    28          True
# 19  643f5aa8a25946234c8eefd3       Andrés   Iniesta    30          True
# 20  643f5aa8a25946234c8eefd4     Fernando    Torres    30          True
# 21  643fe440c87fb840a2285dd9         Iker  Casillas    65          True
# 22  643fe440c87fb840a2285dda       Carles     Puyol    65         False
# 23  643fe441c87fb840a2285ddb       Sergio     Ramos    28          True
# 24  643fe441c87fb840a2285ddc       Andrés   Iniesta    30          True
# 25  643fe441c87fb840a2285ddd     Fernando    Torres    30          True

# %%
df.columns
# Out:
# Index(['_id', 'nombre', 'apellidos', 'edad', 'internacional'], dtype='object')

# %%
df = df.drop_duplicates(subset=["nombre",  "apellidos"])

df
# Out:
#                          _id       nombre apellidos  edad internacional
# 0   643d7af4212a0ef1d288eb96       Carles     Puyol    65             1
# 1   643d7af4212a0ef1d288eb97       Sergio     Ramos    28          True
# 2   643d7af5212a0ef1d288eb98  Andrés Juan   Iniesta    30          True
# 3   643d7af5212a0ef1d288eb99     Fernando    Torres    30          True
# 16  643f5aa7a25946234c8eefd0         Iker  Casillas    65          True
# 19  643f5aa8a25946234c8eefd3       Andrés   Iniesta    30          True

# %%
df["Nacionalidad"] = "Españoles"
df
# Out:
# /var/folders/1r/gvzp1f_j02z_4d3k62n05zsm0000gn/T/ipykernel_38352/1625542393.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Nacionalidad"] = "Españoles"
#                          _id       nombre apellidos  edad internacional
# 0   643d7af4212a0ef1d288eb96       Carles     Puyol    65             1  \
# 1   643d7af4212a0ef1d288eb97       Sergio     Ramos    28          True
# 2   643d7af5212a0ef1d288eb98  Andrés Juan   Iniesta    30          True
# 3   643d7af5212a0ef1d288eb99     Fernando    Torres    30          True
# 16  643f5aa7a25946234c8eefd0         Iker  Casillas    65          True
# 19  643f5aa8a25946234c8eefd3       Andrés   Iniesta    30          True
#
#    Nacionalidad
# 0     Españoles
# 1     Españoles
# 2     Españoles
# 3     Españoles
# 16    Españoles
# 19    Españoles

# %%
df1 = df.drop(["_id"], axis=1)

df1
# Out:
#          nombre apellidos  edad internacional Nacionalidad
# 0        Carles     Puyol    65             1    Españoles
# 1        Sergio     Ramos    28          True    Españoles
# 2   Andrés Juan   Iniesta    30          True    Españoles
# 3      Fernando    Torres    30          True    Españoles
# 16         Iker  Casillas    65          True    Españoles
# 19       Andrés   Iniesta    30          True    Españoles

# %%
df
# Out:
#                          _id       nombre apellidos  edad internacional
# 0   643d7af4212a0ef1d288eb96       Carles     Puyol    65             1  \
# 1   643d7af4212a0ef1d288eb97       Sergio     Ramos    28          True
# 2   643d7af5212a0ef1d288eb98  Andrés Juan   Iniesta    30          True
# 3   643d7af5212a0ef1d288eb99     Fernando    Torres    30          True
# 16  643f5aa7a25946234c8eefd0         Iker  Casillas    65          True
# 19  643f5aa8a25946234c8eefd3       Andrés   Iniesta    30          True
#
#    Nacionalidad
# 0     Españoles
# 1     Españoles
# 2     Españoles
# 3     Españoles
# 16    Españoles
# 19    Españoles

# %%
df1.at[3, "nombre"] = "Diego"

df1
# Out:
#          nombre apellidos  edad internacional Nacionalidad
# 0        Carles     Puyol    65             1    Españoles
# 1        Sergio     Ramos    28          True    Españoles
# 2   Andrés Juan   Iniesta    30          True    Españoles
# 3         Diego    Torres    30          True    Españoles
# 16         Iker  Casillas    65          True    Españoles
# 19       Andrés   Iniesta    30          True    Españoles

# %%
df2 = df1.drop([16])
df2
# Out:
#          nombre apellidos  edad internacional Nacionalidad
# 0        Carles     Puyol    65             1    Españoles
# 1        Sergio     Ramos    28          True    Españoles
# 2   Andrés Juan   Iniesta    30          True    Españoles
# 3         Diego    Torres    30          True    Españoles
# 19       Andrés   Iniesta    30          True    Españoles

# %%
df2.loc[2]= ["James", "Rodriguez", 36, False, "Colombiana"]

df2
# Out:
#     nombre  apellidos  edad internacional Nacionalidad
# 0   Carles      Puyol    65             1    Españoles
# 1   Sergio      Ramos    28          True    Españoles
# 2    James  Rodriguez    36         False   Colombiana
# 3    Diego     Torres    30          True    Españoles
# 19  Andrés    Iniesta    30          True    Españoles

# %%
df2.loc[(df2["edad"] <  40)  & (df2["Nacionalidad"] == "Colombiana") ]
# Out:
#   nombre  apellidos  edad internacional Nacionalidad
# 2  James  Rodriguez    36         False   Colombiana
